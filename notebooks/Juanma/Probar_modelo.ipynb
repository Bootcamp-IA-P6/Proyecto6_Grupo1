# %%
import pandas as pd
import joblib
import xgboost as xgb

# %%
# --- 1. Cargar el modelo ---
modelo_cargado = joblib.load('../../models/Juanma/modelo_XGBClassifier.joblib')

# %%
# --- 2. Preparar nuevos datos con Pandas ---
nuevos_datos = pd.DataFrame({
    'Acidity': [7.58, 7.42, 7], 'Aftertaste': [7.75, 7.33, 7.5], 'Aroma': [7.83, 7.17, 7.5], 'Balance': [8.00, 7.42, 9], 'Body': [7.67, 7.33, 7.5],
    'Category One Defects': [0, 0, 0], 'Category Two Defects': [2, 0, 0], 'Flavor': [7.58, 7.42, 9], 'altitud_limpia': [2560.00, 1320.21, 1200],
    'Color_Blue-Green': [False, False, False], 'Color_Bluish-Green': [False, True, False], 'Color_Brown': [False, False, False],
    'Color_Green': [True, False, True], 'Color_Yellow': [False, False, False], 'Color_Yellow Green': [False, False, False]
})

# %%
# --- 3. Predecir ---
predicciones = modelo_cargado.predict(nuevos_datos)
print(f"Nuevas predicciones: {predicciones}")
# Out:
# Nuevas predicciones: [1 0 1]
