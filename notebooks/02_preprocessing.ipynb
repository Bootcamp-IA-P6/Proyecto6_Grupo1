# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Cargamos el archivo que generamos al final del EDA
df = pd.read_csv('../data/processed/coffee_combined_cleaned.csv')

print(f"✅ Dataset cargado con {df.shape[0]} filas.")
# Out:
# ✅ Dataset cargado con 1518 filas.

# %%
import pandas as pd
import numpy as np

# 1. Identificamos qué columnas son numéricas y cuáles no
# Esto es más seguro que preguntar por 'object'
cols_numericas = df.select_dtypes(include=[np.number]).columns
cols_categoricas = df.select_dtypes(exclude=[np.number]).columns

# 2. Rellenamos las numéricas con la MEDIANA
for col in cols_numericas:
    df[col] = df[col].fillna(df[col].median())

# 3. Rellenamos las categóricas con 'Unknown'
for col in cols_categoricas:
    df[col] = df[col].fillna('Unknown')

print("✅ Valores nulos gestionados correctamente.")
print(f"Columnas numéricas tratadas: {len(cols_numericas)}")
print(f"Columnas de texto tratadas: {len(cols_categoricas)}")
# Out:
# ✅ Valores nulos gestionados correctamente.
# Columnas numéricas tratadas: 14
# Columnas de texto tratadas: 2

# %%
# Creamos el codificador
le = LabelEncoder()

# Lista de columnas de texto
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df[col] = le.fit_transform(df[col].astype(str))
    print(f"Categoría '{col}' codificada.")

print("\n✅ ¡Ahora todo el dataset es numérico!")
df.head()
# Out:
# Categoría 'Country of Origin' codificada.
# Categoría 'Color' codificada.
#
# ✅ ¡Ahora todo el dataset es numérico!
# /var/folders/1p/w3s14y4d6h73sf2yqfjwgs2w0000gn/T/ipykernel_90666/973820719.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=['object']).columns
#    Country of Origin  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  \
# 0                  3   8.58    8.50        8.42     8.58  8.25     8.42
# 1                 28   8.50    8.50        7.92     8.00  7.92     8.25
# 2                 16   8.33    8.42        8.08     8.17  7.92     8.17
# 3                  4   8.08    8.17        8.17     8.25  8.17     8.08
# 4                  3   8.33    8.33        8.08     8.25  7.92     7.92
#
#    Uniformity  Clean Cup  Sweetness  Moisture Percentage  \
# 0        10.0       10.0       10.0                 11.8
# 1        10.0       10.0       10.0                 10.5
# 2        10.0       10.0       10.0                 10.4
# 3        10.0       10.0       10.0                 11.8
# 4        10.0       10.0       10.0                 11.6
#
#    Category One Defects  Quakers  Color  Category Two Defects  is_specialty
# 0                     0      0.0      8                     3             1
# 1                     0      0.0      4                     0             1
# 2                     0      0.0     15                     2             1
# 3                     0      0.0      8                     0             1
# 4                     0      2.0     14                     2             1

# %%
# Guardamos la versión lista para Machine Learning
ruta_save = '../data/processed/coffee_preprocessed.csv'
df.to_csv(ruta_save, index=False)

print(f"💾 Archivo guardado en: {ruta_save}")
# Out:
# 💾 Archivo guardado en: ../data/processed/coffee_preprocessed.csv
